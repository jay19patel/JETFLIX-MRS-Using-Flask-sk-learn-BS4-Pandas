# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('all_csv/Anime.csv')

# %%
df = df.drop(['video'], axis=1)

# %%
df = df.replace(to_replace="None", value=np.nan)

# %%
df["Imdb_rating"] = df["Imdb_rating"].str.replace("IMDb ", "")

# %%
df = df.dropna()

# %%
sorted_data = df.sort_values(by='Imdb_rating', ascending=False)[0:6]
#return sorted_data.values.tolist()

# %%
sorted_data
# Out:
#    Unnamed: 0                                   title  \
# 6           6  EVANGELION:2.22 YOU CAN (NOT) ADVANCE.
# 0           0                        Jujutsu Kaisen 0
# 3           3    EVANGELION:1.11 YOU ARE (NOT) ALONE.
# 7           7     EVANGELION:3.33 YOU CAN (NOT) REDO.
# 1           1           LEGO Marvel: Maximum Overload
# 2           2             LUPIN THE 3rd vs. CAT’S EYE
#
#                                           disciption Imdb_rating  \
# 6  Mari Illustrious-Makinami pilots Provisional U...         7.9
# 0  Yuta Okkotsu witnessed the death of his childh...         7.8
# 3  Scarred by the Second Impact, the Fourth Angel...         7.6
# 7  Shinji wakes after 14 years aboard the battles...         6.9
# 1  Spider-Man and Marvel's Super Heroes take on a...         6.3
# 2  Hitomi, Rui, and Ai are sisters and cat burgla...         6.0
#
#                                               genres  Released_date  \
# 6  Science Fiction·Animation·Electrifying·Futuristic           2009
# 0                       Animation·Horror·Drama·Anime           2022
# 3  Science Fiction·Animation·Electrifying·Futuristic           2008
# 7  Science Fiction·Animation·Electrifying·Futuristic           2013
# 1                     Kids·Anime·Ambitious·Emotional           2013
# 2                                              Anime           2023
#
#                                            image_url  \
# 6  https://images-eu.ssl-images-amazon.com/images...
# 0  https://images-eu.ssl-images-amazon.com/images...
# 3  https://images-eu.ssl-images-amazon.com/images...
# 7  https://images-eu.ssl-images-amazon.com/images...
# 1  https://images-eu.ssl-images-amazon.com/images...
# 2  https://images-eu.ssl-images-amazon.com/images...
#
#                                          webpage_url
# 6  https://www.primevideo.com/detail/0GI1ZOJJGCMF...
# 0  https://www.primevideo.com/detail/0GTVYMIYD1GS...
# 3  https://www.primevideo.com/detail/0K1XKKH7C44W...
# 7  https://www.primevideo.com/detail/0KRIACGNJC4V...
# 1  https://www.primevideo.com/detail/0NYJEB34YEBU...
# 2  https://www.primevideo.com/detail/0JHJJJYBCOBY...

# %%
df
# Out:
#    Unnamed: 0                                   title  \
# 0           0                        Jujutsu Kaisen 0
# 1           1           LEGO Marvel: Maximum Overload
# 2           2             LUPIN THE 3rd vs. CAT’S EYE
# 3           3    EVANGELION:1.11 YOU ARE (NOT) ALONE.
# 5           5               LEGO Marvel Black Panther
# 6           6  EVANGELION:2.22 YOU CAN (NOT) ADVANCE.
# 7           7     EVANGELION:3.33 YOU CAN (NOT) REDO.
# 8           8    LEGO Marvel: Guardians of the Galaxy
#
#                                           disciption Imdb_rating  \
# 0  Yuta Okkotsu witnessed the death of his childh...         7.8
# 1  Spider-Man and Marvel's Super Heroes take on a...         6.3
# 2  Hitomi, Rui, and Ai are sisters and cat burgla...         6.0
# 3  Scarred by the Second Impact, the Fourth Angel...         7.6
# 5  Ulysses Klaue and Eric Killmonger are back to ...         5.6
# 6  Mari Illustrious-Makinami pilots Provisional U...         7.9
# 7  Shinji wakes after 14 years aboard the battles...         6.9
# 8  Guardians of the Galaxy: The Thanos Threat is ...         5.8
#
#                                               genres  Released_date  \
# 0                       Animation·Horror·Drama·Anime           2022
# 1                     Kids·Anime·Ambitious·Emotional           2013
# 2                                              Anime           2023
# 3  Science Fiction·Animation·Electrifying·Futuristic           2008
# 5          Science Fiction·Comedy·Exciting·Fantastic           2018
# 6  Science Fiction·Animation·Electrifying·Futuristic           2009
# 7  Science Fiction·Animation·Electrifying·Futuristic           2013
# 8               Science Fiction·Comedy·Animation·Fun           2017
#
#                                            image_url  \
# 0  https://images-eu.ssl-images-amazon.com/images...
# 1  https://images-eu.ssl-images-amazon.com/images...
# 2  https://images-eu.ssl-images-amazon.com/images...
# 3  https://images-eu.ssl-images-amazon.com/images...
# 5  https://images-eu.ssl-images-amazon.com/images...
# 6  https://images-eu.ssl-images-amazon.com/images...
# 7  https://images-eu.ssl-images-amazon.com/images...
# 8  https://images-eu.ssl-images-amazon.com/images...
#
#                                          webpage_url
# 0  https://www.primevideo.com/detail/0GTVYMIYD1GS...
# 1  https://www.primevideo.com/detail/0NYJEB34YEBU...
# 2  https://www.primevideo.com/detail/0JHJJJYBCOBY...
# 3  https://www.primevideo.com/detail/0K1XKKH7C44W...
# 5  https://www.primevideo.com/detail/0FBDCOKUAG7O...
# 6  https://www.primevideo.com/detail/0GI1ZOJJGCMF...
# 7  https://www.primevideo.com/detail/0KRIACGNJC4V...
# 8  https://www.primevideo.com/detail/0FWOM5WG4FK3...
